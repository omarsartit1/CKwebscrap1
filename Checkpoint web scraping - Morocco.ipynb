# %%
import requests
import string
from bs4 import BeautifulSoup

# %%
Enter_input = "Python (programming language)"
print(Enter_input)
# Out:
# Python (programming language)

# %%
lists = Enter_input.split()  # splits by spaces by default, can be changed
lists
# Out:
# ['Python', '(programming', 'language)']

# %%
word = "_".join(lists)
word
# Out:
# 'Python_(programming_language)'

# %%
url = "https://en.wikipedia.org/wiki/"+word  # to create a valid wikipedia url
print(url)
# Out:
# https://en.wikipedia.org/wiki/Python_(programming_language)

# %%
def getlinks(url):
    url_open = requests.get(url)
    soup = BeautifulSoup(url_open.content, 'html.parser')
    
    links = [a.get('href') for a in soup.find_all('a')]  # get all the attributes "href" from all the elements <a>
    for i in links:
        print(i)

# %%
def wikibot(url):
    url_open = requests.get(url)
    soup = BeautifulSoup(url_open.content, 'html.parser')
    
    details = soup('table', {'class':'infobox'})

    for i in details:
        h = i.find_all('tr')
        for j in h:
            heading = j.find_all('th')
            detail = j.find_all('td')
            if heading is not None and detail is not None:
                for x,y in zip(heading,detail):
                    print(f"{x.text} :: {y.text}")
                    print("-------------------")
                    
    for i in range(1,3):  # skipped 0 because it's an empty string
        p = soup('p')
        print(p[i].text)

getlinks(url)
# Out:
# #bodyContent
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Main_Page
# /wiki/Special:Search
# /w/index.php?title=Special:CreateAccount&returnto=Python+%28programming+language%29
# /w/index.php?title=Special:UserLogin&returnto=Python+%28programming+language%29
# /w/index.php?title=Special:CreateAccount&returnto=Python+%28programming+language%29
# /w/index.php?title=Special:UserLogin&returnto=Python+%28programming+language%29
# /wiki/Help:Introduction
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# #
# #History
# #Design_philosophy_and_features
# ...
